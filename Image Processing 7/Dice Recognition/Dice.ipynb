# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("img/0.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_canny = cv2.Canny(img_gray,0,255)
plt.imshow(img_canny,cmap="gray")

# %%
img_thresh=cv2.adaptiveThreshold(img_canny,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,7,5)
kernel = np.ones((9,9),np.uint8)
img_thresh = cv2.dilate(img_thresh,kernel,iterations = 1)
plt.imshow(img_thresh,cmap="gray")

# %%
contours,_ = cv2.findContours(img_thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
x,y,w,h = cv2.boundingRect(contours[0])
dice = img_thresh[y:y+h,x:x+w]

# %%
contours,hierarchy = cv2.findContours(dice,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
first_child = hierarchy[0][:,2]>0
count = np.bincount(first_child)[0]
print("Dice Recognition: ",count)
# Out:
# Dice Recognition:  2

# %%
cv2.rectangle(img_rgb,(x,y),(x+w,y+h),(0,0,255),4)
cv2.putText(img_rgb,f"Dice Recognition:{count}", (x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255),2)
plt.imshow(img_rgb)

# %%
img = cv2.imread("img/1.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_gray,cmap="gray")

# %%
img_thresh=cv2.adaptiveThreshold(img_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,75,15)
kernel = kernel = np.ones((13,13),np.uint8)
img_thresh = cv2.dilate(img_thresh,kernel,iterations = 1)
plt.imshow(img_thresh,cmap="gray")

# %%
contours,_ = cv2.findContours(img_thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
x1,y1,w1,h1 = cv2.boundingRect(contours[0])
x2,y2,w2,h2 = cv2.boundingRect(contours[1])
dice1 = img_thresh[y1:y1+h1,x1:x1+w1]
dice2 = img_thresh[y2:y2+h2,x2:x2+w2]

# %%
contours1,hierarchy1 = cv2.findContours(dice1,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
contours2,hierarchy2 = cv2.findContours(dice2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
first_child1 = hierarchy1[0][:,2]>0
count1 = np.bincount(first_child1)[0]

first_child2 = hierarchy2[0][:,2]>0
count2 = np.bincount(first_child2)[0]
print("Dice Recognition: ",count1,count2)
# Out:
# Dice Recognition:  3 4

# %%
cv2.rectangle(img_rgb,(x1,y1),(x1+w1,y1+h1),(0,0,255),4)
cv2.rectangle(img_rgb,(x2,y2),(x2+w2,y2+h2),(0,0,255),4)
cv2.putText(img_rgb,f"Dice Recognition:{count1}", (x1,y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,255),1)
cv2.putText(img_rgb,f"Dice Recognition:{count2}", (x2,y2-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,255),1)
plt.imshow(img_rgb)

# %%
img = cv2.imread("img/2.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_gray,cmap="gray")

# %%
img_thresh=cv2.adaptiveThreshold(img_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,255,5)
kernel = kernel = np.ones((15,15),np.uint8)
img_thresh = cv2.dilate(img_thresh,kernel,iterations = 1)
plt.imshow(img_thresh,cmap="gray")

# %%
contours,_ = cv2.findContours(img_thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
x1,y1,w1,h1 = cv2.boundingRect(contours[0])
x2,y2,w2,h2 = cv2.boundingRect(contours[1])
x3,y3,w3,h3 = cv2.boundingRect(contours[2])
dice1 = img_thresh[y1:y1+h1,x1:x1+w1]
dice2 = img_thresh[y2:y2+h2,x2:x2+w2]
dice3 = img_thresh[y3:y3+h3,x3:x3+w3]

# %%
contours1,hierarchy1 = cv2.findContours(dice1,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
contours2,hierarchy2 = cv2.findContours(dice2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
contours3,hierarchy3 = cv2.findContours(dice3,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
first_child1 = hierarchy1[0][:,2]>0
count1 = np.bincount(first_child1)[0]

first_child2 = hierarchy2[0][:,2]>0
count2 = np.bincount(first_child2)[0]

first_child3 = hierarchy3[0][:,2]>0
count3 = np.bincount(first_child3)[0]
print("Dice Recognition: ",count1,count2,count3)
# Out:
# Dice Recognition:  3 6 1

# %%
cv2.rectangle(img_rgb,(x1,y1),(x1+w1,y1+h1),(0,0,255),4)
cv2.rectangle(img_rgb,(x2,y2),(x2+w2,y2+h2),(0,0,255),4)
cv2.rectangle(img_rgb,(x3,y3),(x3+w3,y3+h3),(0,0,255),4)
cv2.putText(img_rgb,f"Dice Recognition:{count1}", (x1,y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.80, (255,0,255),2)
cv2.putText(img_rgb,f"Dice Recognition:{count2}", (x2,y2-10), cv2.FONT_HERSHEY_SIMPLEX, 0.80, (255,0,255),2)
cv2.putText(img_rgb,f"Dice Recognition:{count3}", (x3,y3-10), cv2.FONT_HERSHEY_SIMPLEX, 0.80, (255,0,255),2)
plt.imshow(img_rgb)

# %%
img = cv2.imread("img/3.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_canny = cv2.Canny(img_gray,255,255)
plt.imshow(img_canny,cmap="gray")

# %%
img_thresh=cv2.adaptiveThreshold(img_canny,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,5,30)
kernel = kernel = np.ones((5,5),np.uint8)
img_thresh = cv2.dilate(img_thresh,kernel,iterations = 1)
plt.imshow(img_thresh,cmap="gray")

# %%
contours,_ = cv2.findContours(img_thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
x1,y1,w1,h1 = cv2.boundingRect(contours[0])
x2,y2,w2,h2 = cv2.boundingRect(contours[1])
dice1 = img_thresh[y1:y1+h1,x1:x1+w1]
dice2 = img_thresh[y2:y2+h2,x2:x2+w2]

# %%
contours1,hierarchy1 = cv2.findContours(dice1,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
contours2,hierarchy2 = cv2.findContours(dice2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
first_child1 = hierarchy1[0][:,2]>0
count1 = np.bincount(first_child1)[0]

first_child2 = hierarchy2[0][:,2]>0
count2 = np.bincount(first_child2)[0]
print("Dice Recognition: ",count1,count2)
# Out:
# Dice Recognition:  5 1

# %%
cv2.rectangle(img_rgb,(x1,y1),(x1+w1,y1+h1),(0,0,255),4)
cv2.rectangle(img_rgb,(x2,y2),(x2+w2,y2+h2),(0,0,255),4)
cv2.putText(img_rgb,f"Dice Recognition:{count1}", (x1,y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255,0,255),2)
cv2.putText(img_rgb,f"Dice Recognition:{count2}", (x2,y2-10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255,0,255),2)
plt.imshow(img_rgb)
